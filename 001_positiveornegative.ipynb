# %% [markdown]
# Check if a Number is Positive and Negative in Python

# %%
num = -20

if num > 0:
    print("positive")
elif num < 0:
    print("negative")
else:
    print("zero or undefined")
# Out:
# negative
